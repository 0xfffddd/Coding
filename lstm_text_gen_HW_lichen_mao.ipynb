# %% [markdown]
# <a href="https://colab.research.google.com/github/0xfffddd/Coding/blob/main/lstm_text_gen_HW_lichen_mao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Long Short-term Memory for Text Generation

# %% [markdown]
# This notebook uses LSTM neural network to generate text from Nietzsche's writings.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import random
import sys
import io


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.utils import get_file

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Get the data
# Nietzsche's writing dataset is available online. The following code download the dataset.

# %%
path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step

# %% [markdown]
# ### Visualize data

# %%
print('corpus length:', len(text))
# Out:
# corpus length: 600893

# %%
print(text[10:513])
# Out:
# supposing that truth is a woman--what then? is there not ground
# for suspecting that all philosophers, in so far as they have been
# dogmatists, have failed to understand women--that the terrible
# seriousness and clumsy importunity with which they have usually paid
# their addresses to truth, have been unskilled and unseemly methods for
# winning a woman? certainly she has never allowed herself to be won; and
# at present every kind of dogma stands with sad and discouraged mien--if,
# indeed, it stands at all!

# %%
chars = sorted(list(set(text)))
# total nomber of characters
print('total chars:', len(chars))
# Out:
# total chars: 57

# %% [markdown]
# ### Clean data
#
# We cut the text in sequences of maxlen characters with a jump size of 3.
# The features for each example is a matrix of size maxlen*num of chars.
# The label for each example is a vector of size num of chars, which represents the next character.

# %%
# create (character, index) and (index, character) dictionary
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %% [markdown]
# ### Vecterization **This vectorization procedure includes a one-hot-encoding for each word, and therefore, an Embedding layer should not be used. If you want to use an Embedding layer. You will need to revise this block. **

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# ## The model

# %% [markdown]
# ### Build the model - fill in this box

# %% [markdown]
# we need a recurrent layer with input shape (maxlen, len(chars)) and a dense layer with output size  len(chars)

# %%
model = keras.Sequential()
model.add(layers.Input((maxlen, len(chars))))  # (40,57)

model.add(layers.LSTM(128, return_sequences=True, dropout=0.2, recurrent_dropout=0))
model.add(layers.LSTM(128, return_sequences=True, dropout=0.2, recurrent_dropout=0.))
model.add(layers.LSTM(128, return_sequences=False, dropout=0.2, recurrent_dropout=0))

model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = optimizers.RMSprop(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 40, 128)        │        95,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 40, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 57)             │         7,353 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 365,753 (1.40 MB)
#  Trainable params: 365,753 (1.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Inspect the model
#
# Use the `.summary` method to print a simple description of the model

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 40, 128)        │        95,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 40, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 57)             │         7,353 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 365,753 (1.40 MB)
#  Trainable params: 365,753 (1.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
class PrintLoss(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, _):
        # Function invoked at end of each epoch. Prints generated text.
        print()
        print('----- Generating text after Epoch: %d' % epoch)

        start_index = random.randint(0, len(text) - maxlen - 1)
        for diversity in [0.5, 1.0]:
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(400):
                x_pred = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x_pred[0, t, char_indices[char]] = 1.

                preds = model.predict(x_pred, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()

# %%
EPOCHS = 60
BATCH = 128

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)

history = model.fit(x, y,
                    batch_size = BATCH,
                    epochs = EPOCHS,
                    validation_split = 0.2,
                    verbose = 1,
                    callbacks = [early_stop, PrintLoss()])
# Out:
# Epoch 1/60
# 1249/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1517 - loss: 3.0560
# ----- Generating text after Epoch: 0
# ----- diversity: 0.5
# ----- Generating with seed: "im with his dressing-gown!--i meant to s"
# im with his dressing-gown!--i meant to smaes oe tee arsstta ae tad arasa ie ertete in on an te to amee ao a e htho e a  sod ae ant uo o en is opisa e io e e eri oe ir ans ii oss ta aa  ae eee on oee tonte iie iis ien hhe ie ia eote ee tio on, tie woe,, an a ai th eettin hftto a ue ai edso in oe oasta e irtoe ito ie ta e ua tee tin irdte ie an onr ae ann stied eatsi re hho tar oe brtta  oe a ies ia lna to he i ha ti e anr th a toons thn
# ----- diversity: 1.0
# ----- Generating with seed: "im with his dressing-gown!--i meant to s"
# im with his dressing-gown!--i meant to seei pthnti
# osvnweidfpotoce, whotasomheleye arunedio-cay annbihantoedieiaalwh anvtrnwihne atartrrtprha o orrrs o ovlnudal io n
# m oe,d las ebectto oton o e had e mj ev on wsemptnci aa w iot f ftde el,ttgaa ssos are3ta otresynwutfpihietbi ie senis,dion sa on oilaegitelti wi io "rimenlti eatwdcyenshi lorbdlnss h ar tirnvage trita .wtasedenlftow onphunbe oi entfrtb?e
# ie ata se aeb,mhteus ti pa gped;cra
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 80s 61ms/step - accuracy: 0.1518 - loss: 3.0558 - val_accuracy: 0.2226 - val_loss: 2.7939
# Epoch 2/60
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2214 - loss: 2.7800
# ----- Generating text after Epoch: 1
# ----- diversity: 0.5
# ----- Generating with seed: " in my opinion, he is a true friend of w"
#  in my opinion, he is a true friend of whimin on poot of whe hor bor the in with on the the bor the sret the simanr if the the fers roth in thac and at in the home the se thes the wort the hercter the his the hrane mut ln as harint the and and the hhilt in bose an cererine the hare in ande to and is thererthe ant brrios at of the sine if the perion on an thar ser cors the herhe on thes thet and ass borerse the hons ther fominlt sor of p
# ----- diversity: 1.0
# ----- Generating with seed: " in my opinion, he is a true friend of w"
#  in my opinion, he is a true friend of whes un aswmote peimh ther ths gfn!h, a bhirurte al of bodigc ols porandd)e, of aupt; ose at
# ferentas thed arwiit, to wuves. cod olits wovg theb gecieanod int hend pawicepe nace
# ood themb e poris
# as it in cors, noc
# lsfenco
# do-o , an od whm han the the fecyt
# brtrt dmy itis os penkatify csabess ofth amer ralar hoph late inciut
# besiire of mot so. int sodh rfinob tam teme lckyvo at ulh wunt ar ofinethe
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 76s 60ms/step - accuracy: 0.2214 - loss: 2.7799 - val_accuracy: 0.3108 - val_loss: 2.3840
# Epoch 3/60
# 1250/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2819 - loss: 2.4881
# ----- Generating text after Epoch: 2
# ----- diversity: 0.5
# ----- Generating with seed: "seldom err.--plato
# did all he could to i"
# seldom err.--plato
# did all he could to is dase he incer it the mor mune and the solt, of a somun the rectuon and the kint herer of the cich and in coren in the shicitifed and and is the mer and it the in and praale the has he dense and and as and the merin of the gorition in that the be pan to o whe secher as the suct the love in and and the mimhe in the soress and of the slominn the hid entires and the gindering of in gich to hir the h
# ----- diversity: 1.0
# ----- Generating with seed: "seldom err.--plato
# did all he could to i"
# seldom err.--plato
# did all he could to is dom is reape isz e the
# whukun a
# tommend, ay if are nithily i bew of he is atf of hor
# mensy if caval char coe meln", "o amertsit of his is
# there mery wemeent the furpen and ut soserms th neygersy ha ta wowh thio were the a maning and hawscarituy and reyt he hikgeriol the plaks tte onchhonnd, cilhonl aw who ans efves af a tis hove palt in thi kood is whas his "has to pand to som ll-innefse a roleo
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.2819 - loss: 2.4880 - val_accuracy: 0.3603 - val_loss: 2.1845
# Epoch 4/60
# 1248/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3188 - loss: 2.3433
# ----- Generating text after Epoch: 3
# ----- diversity: 0.5
# ----- Generating with seed: "losopher who, as a genuine
# englishman, t"
# losopher who, as a genuine
# englishman, that ever in and in and it that the meaps as for whath sove har the pore in the was sore world fured and the sead mast of the conf and to forn the nother the dave and of the henting of the condences--chomes of the in the consion of sorl of in which interponaricy that the sepnon and and to not it the expeles, and the renain of the in ond to whal the
# hink it coes the precenth exrendion to corseds of
# ----- diversity: 1.0
# ----- Generating with seed: "losopher who, as a genuine
# englishman, t"
# losopher who, as a genuine
# englishman, the tomellity
# of
# wald thathere, be. as waued ent-:em
# the histar exwecncty: if forction limation:10id mesares retirat for goundity that in as ly minkë--winh tas
# the go biss abd forph, that in gose and
# heprean bavise and thery ot selfneds e"sranm! und that dod motr dearliced"--da of ins in mi comuritif yenged nove, in winchs and ringfimgen mure he seed he woun it hat ituls the pararisg awlor"
# beard.
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.3188 - loss: 2.3432 - val_accuracy: 0.3912 - val_loss: 2.0578
# Epoch 5/60
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3417 - loss: 2.2488
# ----- Generating text after Epoch: 4
# ----- diversity: 0.5
# ----- Generating with seed: "lect, the cultured class.
#
# 264. it canno"
# lect, the cultured class.
#
# 264. it cannould of the prosent for an every the grice, and the coued to the sealle to some the preting as the conself that the portion of the man te strality to se anlenge, the
# sanien and phenery they conden and masters and there porally the pringers whot the man ale pracing be
# beation and consintion and pentule of the reos and haw the cowtand piriens and sourd of the no efpente to an alling an seprection in
# ----- diversity: 1.0
# ----- Generating with seed: "lect, the cultured class.
#
# 264. it canno"
# lect, the cultured class.
#
# 264. it cannong. "y hos duve
# aromnly the popirinion efuits hid yreal wo mide in amls buth couptunity everong desyem nfut that for shuch or sauve way (ot and insiling of there
# leverion fimhter tither datulle the mivat and calsepf meach. of a varutil porting? a beler,
# of roluge to a gerfentility, ove greutedy whrt at das be lativations"--is the in jinerery ving cumland and prese to the mishleade, the porised maw
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.3417 - loss: 2.2487 - val_accuracy: 0.4152 - val_loss: 1.9726
# Epoch 6/60
# 1247/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3611 - loss: 2.1775
# ----- Generating text after Epoch: 5
# ----- diversity: 0.5
# ----- Generating with seed: "ing simple; and the whole of morality is"
# ing simple; and the whole of morality is the sould and he have decerstions of the coust and and soman to the suntion of the
# pristuve of the mant fror but the whild him man dabturice of expection of the sencection a pristion. and sementhe a corpurity--be wand and in bist very in the been and it the suefer and the has the san its as and has that beanned the will and and not even at is the merserfuch, the some time the a mentions and sente
# ----- diversity: 1.0
# ----- Generating with seed: "ing simple; and the whole of morality is"
# ing simple; and the whole of morality is dis als diccrion--douldable auly2that "relfl and tho riniem
# so for it is ware; and and exuretucf, the inetimating of lem;--the senfesions the a phulichity, sching of utter and affen of
# mon a
# alvime wimest of
# that nourh intonly whe his to dacans lancl, itan not a rafproon and corur,-tithituess and gortereranily ofe to   "onsed ano
# brecsels, when at in seashed these
# penvoriony to raderor in to even
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.3611 - loss: 2.1774 - val_accuracy: 0.4382 - val_loss: 1.8939
# Epoch 7/60
# 1251/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3763 - loss: 2.1232
# ----- Generating text after Epoch: 6
# ----- diversity: 0.5
# ----- Generating with seed: ". it is always more obvious to me that t"
# . it is always more obvious to me that the mavar as the mort of the more so the entinion of the distion of his in the conmenion sise to the most the denine the sensent in the somence of which compenally in his his his to in only it is are not of man dight the more man even which the self--the sould of the invertion of the cores of the mast the man the sunfering of the conterial bean in man do preestion, and to the everytopres concence o
# ----- diversity: 1.0
# ----- Generating with seed: ". it is always more obvious to me that t"
# . it is always more obvious to me that to
# veryt, the fort of mealininasee tund of its olle men levevinise,
# their but when condreningy, it be is but us, in relaused whot. ilve,ly, his fyaiture, sed alsunt: foomelity, ancigedame an in of the preidus fror can hese at therd rusted hivatein abinof is fouress to the rovinise of grome
# thes sumethation
# as thems beingromal rai him. forceln altioms to ereation beef to the lost;r
# with would hit al
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.3763 - loss: 2.1232 - val_accuracy: 0.4534 - val_loss: 1.8481
# Epoch 8/60
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3876 - loss: 2.0885
# ----- Generating text after Epoch: 7
# ----- diversity: 0.5
# ----- Generating with seed: "s a well stacked and ever renewed ware-e"
# s a well stacked and ever renewed ware-eor
# sore supe with have the
# preated of the world every is man and astert the bentimes and the mane there were seem, in the conders of the never of the is and conders and and canticate be conse a surf stand age do phen of an alother and one in so cate,
# in alotr and the rire of the strendens and of the consupe the seees be only a preasion of the grest in the faith consers in a great of the from the r
# ----- diversity: 1.0
# ----- Generating with seed: "s a well stacked and ever renewed ware-e"
# s a well stacked and ever renewed ware-eemaness which adeased and prosimacett and whet fat s1ries of to he dfally in the alougtless,
# the slepess feeted man bearnto tkild ne somether
# formng what clodicsity an arlivaite acreasciolly is romegis ad in preprolit to the
# stourd as wes,
# lef one ther manion
# vate--bot have citss; thene in their seemethy and evead the vofain that so a rives has cansertamed the impeastive sa]
# itself, agoneseres imt
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.3876 - loss: 2.0885 - val_accuracy: 0.4621 - val_loss: 1.8071
# Epoch 9/60
# 1247/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3962 - loss: 2.0540
# ----- Generating text after Epoch: 8
# ----- diversity: 0.5
# ----- Generating with seed: "n image; it cannot do otherwise; philoso"
# n image; it cannot do otherwise; philosophy the are adting to seferity the reman
# of the restred worth and and there is the conserition of the angending and mestain of an the same and sairuality of the more a consical thit is the man some to it is not even who the feee--which such hower and and in the fore the will such and preased and the such the suges of instinct of sense and one self constence, the seepentions which and more and the
# ----- diversity: 1.0
# ----- Generating with seed: "n image; it cannot do otherwise; philoso"
# n image; it cannot do otherwise; philosopabeigm
# that a cenusk
# of momally,
# idelience partion, ferics, to are be
# adtiosate
# to premonias to det phove and elough in ins havacs ethines
# of the gurope--they a cogrected ins time, is
# oll, "woul stame notlry not rfininger uf not ut us recimutesyses hearh
# to geventd and deferisc to simment, stouk the fairly in cotsectime undriesly ciscasnite hy lockity of
# the
# suppesing: must be them notn, bevope w
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 78s 62ms/step - accuracy: 0.3962 - loss: 2.0540 - val_accuracy: 0.4726 - val_loss: 1.7742
# Epoch 10/60
# 1250/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4073 - loss: 2.0199
# ----- Generating text after Epoch: 9
# ----- diversity: 0.5
# ----- Generating with seed: "imself that severity that is so closely "
# imself that severity that is so closely every man, the concernated of the present of the
# presoment and still not that imper the constrence of the form, and intenterneds and loves and perpeating the dost and a belief to the godler to the master and respection of the best in the prochion of the rast has more of the indeding the wayk every in the pore of the tapt of them at belief of the "meason of the suce for the present and possilly of
# ----- diversity: 1.0
# ----- Generating with seed: "imself that severity that is so closely "
# imself that severity that is so closely antimes and sty pompoit vevy matermans some efen undigicely betractity and regect of mistores and world, a gain
# aspresens, and oring as itcon a stind, and every has pleom the boorericed cransual anougute.ris interranny hus elood himsulfen of the rolence of thear
# ploussion.
# ferred, metractung and have in the istermosenals eastical exprasisnan in no dave no insted as the mas theur reture to the c st
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.4073 - loss: 2.0199 - val_accuracy: 0.4822 - val_loss: 1.7430
# Epoch 11/60
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4117 - loss: 1.9953
# ----- Generating text after Epoch: 10
# ----- diversity: 0.5
# ----- Generating with seed: " specimens of humanity whose brains
# thro"
#  specimens of humanity whose brains
# throught in the deally the sain to the concertion of the recenter the
# enely to the suith to them that was to also the world of the fact the philosophy and in all the an is the prease but with the preseddent, and good--the so the man sense in the rease who say to the feetive, the that in the whole for
# the condative the can the mast at all the dastered and the great of which a proforitions and the prebe
# ----- diversity: 1.0
# ----- Generating with seed: " specimens of humanity whose brains
# thro"
#  specimens of humanity whose brains
# throums banan reasore  thing benoms--armormeness and him, to gay sould is farity remaciatangty, nise, and alvetwelt which himsulf, chont
# por, a seegious for hithers--the wittroes is too mink
# prosect of the mate, philosophy
# piritape of the fucs, on mireing the deary being as otgen, leve to
# the rriogingly that the lade.
# -le apseive devection; as ries abonated
# thinor:m thereby action," shithers for thi
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 78s 63ms/step - accuracy: 0.4117 - loss: 1.9953 - val_accuracy: 0.4894 - val_loss: 1.7124
# Epoch 12/60
# 1248/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4159 - loss: 1.9750
# ----- Generating text after Epoch: 11
# ----- diversity: 0.5
# ----- Generating with seed: "nt and refined cruelty. as this is
# growi"
# nt and refined cruelty. as this is
# growinges and the prosent and finder to antigious as the man and in consequence. it is the shome desire which a sight of the wall of the sorgated its instinct of the power distrater to still and the prace, and man a conscience of the refers, and only and one an the rease that it is revald to the prical of the some of fulding, the forman proct of the stronges as the
# spiritude, there the more of the worl
# ----- diversity: 1.0
# ----- Generating with seed: "nt and refined cruelty. as this is
# growi"
# nt and refined cruelty. as this is
# growire, that ore main a prowidiate.
#
# 30. that which
# not enishd canse perhaming! han anislowical to the strudgt to the forlity theare viles it cain, all is sail
# visicate for and the
# lonsedss,
# ven whatever to erestion jyad ty his, rike with german than it wis one
# koanking and inflom consipitions.
#
# _2u.h thy probition, any will the mode on whe have dspord the life, and that the filouarionsolf and also
# hi
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.4159 - loss: 1.9750 - val_accuracy: 0.4953 - val_loss: 1.6917
# Epoch 13/60
# 1249/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4217 - loss: 1.9551
# ----- Generating text after Epoch: 12
# ----- diversity: 0.5
# ----- Generating with seed: "our good musicians themselves
# write badl"
# our good musicians themselves
# write badly the morality of the sanking the concerned that it is the every and sciente and all not the conspined the something the belief and spirit and love of the mast the sense of the come and past in the past of the christion of the serves for the superfain the cause who hay must it is not the sense of far heartes to the
# indiciation of green as is something the hishertic and inderstions and one and such
# ----- diversity: 1.0
# ----- Generating with seed: "our good musicians themselves
# write badl"
# our good musicians themselves
# write badly condeace--from gresn herlembe
# on unage to the inerabler.--the scasen beenther the present foo the persip lation more them mast milover, hif
# order that is parsien presest
# to willy uacking with extarbing now rmmaltang of sers,--whore
# mevally appread to be ideality spenion mad groinher. the
# fidal provend and abless woud ind storlds methy sydmly pown in so themmiser simes of the humonther, betavesou
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 78s 62ms/step - accuracy: 0.4217 - loss: 1.9550 - val_accuracy: 0.5007 - val_loss: 1.6684
# Epoch 14/60
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4268 - loss: 1.9369
# ----- Generating text after Epoch: 13
# ----- diversity: 0.5
# ----- Generating with seed: "trary! on the contrary, my friends! and "
# trary! on the contrary, my friends! and allows of the resurtion of the scient of the more problems of the find of the consciently and extence of the moral of sensent and demined to the ercapned the consequently in only the serman of the mant--which every is the other of the actuined and such recond in the religion, and which all real consequently to has morality to the conscience have how all which which so fir a comporianions in morali
# ----- diversity: 1.0
# ----- Generating with seed: "trary! on the contrary, my friends! and "
# trary! on the contrary, my friends! and badonge woud pasting, moralitune, would, lude and habipe of shurhs who were may of logndd can other, hum, and good inflived,
#  ner even the remain has value,
# in an toever (of comman of, it was not a sexiences in the inauinion of erpender podpleted-to the to "preqeeal ceesent
# to ke "
# refuire cost, ond distruy wh s
# criceiar, graiter, or much
# is reapld extension inms a seealness alword sould no misome
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 78s 62ms/step - accuracy: 0.4268 - loss: 1.9368 - val_accuracy: 0.5054 - val_loss: 1.6537
# Epoch 15/60
# 1250/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4338 - loss: 1.9138
# ----- Generating text after Epoch: 14
# ----- diversity: 0.5
# ----- Generating with seed: "s the superstition
# of schopenhauer puts "
# s the superstition
# of schopenhauer puts and allays have as a free in the lone in the subigious of the sucrestion, and anceptions of the sentiment of the sore been the superfleces the restrates and person of the self--and in the and deal with the will and ambentest the "religion of good perhaps to he perhaps a per
# as be truth to the problemn of their strong of the
# enconterpusion, and the sense of free will the san not the such an extine
# ----- diversity: 1.0
# ----- Generating with seed: "s the superstition
# of schopenhauer puts "
# s the superstition
# of schopenhauer puts loke only here" this self-cermand--whut the coomak" yet yemh and henthares
# leve--the devidudens fight infoctaring suiric- to chilosophy and centappes, are persimes and to youth the conmudal nomely puritity is ordiride can felly be nothom head to their lrssay
# partion
# indechssed are
# belions, that
# we most semmath are provas?
#
#
# l5t those at thichsill, his certain itself-which
# was inmea to
# hiipe," the
#
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.4338 - loss: 1.9138 - val_accuracy: 0.5096 - val_loss: 1.6399
# Epoch 16/60
# 1247/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4358 - loss: 1.9101
# ----- Generating text after Epoch: 15
# ----- diversity: 0.5
# ----- Generating with seed: "f every undertaking, must depend upon th"
# f every undertaking, must depend upon the word of the more fanter of the more of the sensive of the distrustion of the deligious and conscience, the arture of the olding which be semption, such as a consciance of the most most all its are which conscience of the lagt to one of man being him, as all the self-something something, and does the conscience to be referted in reasure, to his faith of the moral of the interpars of the most of t
# ----- diversity: 1.0
# ----- Generating with seed: "f every undertaking, must depend upon th"
# f every undertaking, must depend upon the grester to their find, the ambearous eximitates mean of know have beant, its fleds, and belt"here conselled, in the trit, self,
# indod"d of conscience
# of inscenn?
#
#
# his the cull father and claking even the purliged too jess of sabejet and oble
# sucust
# ald
# the despressions which he shepits its
# dependour
# necessio edrobly himselves, imality in gain reconce of every ewher cike there; what philosophing
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 79s 63ms/step - accuracy: 0.4358 - loss: 1.9101 - val_accuracy: 0.5142 - val_loss: 1.6264
# Epoch 17/60
# 1248/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4404 - loss: 1.8848
# ----- Generating text after Epoch: 16
# ----- diversity: 0.5
# ----- Generating with seed: "he will--uncertain whether to be negativ"
# he will--uncertain whether to be negative of the serve of such so find from the
# conscience, the have whole the free some one satter, the sensent of the men we kind and the more of nother to power of the same to the highertopless, to sempies to the world man in the philosophers it is
# not knowledge and noture of the stas all the conscience, it is not and presents in the word of sains itself and instinction of the
# world and action of the f
# ----- diversity: 1.0
# ----- Generating with seed: "he will--uncertain whether to be negativ"
# he will--uncertain whether to be negative only in present fird discovyms to
# belong to leartt to which should to that we should, as the
# still kinds, should sacre to be origint which the world-tologety; the cellecturs of themsulvess and dearnadity, to as of scanmimation,
# thess ill consemplmes more pitunceing, stronted thas this inducision tour aro in the prines up uversible puit ke toetor. at the fitter to foemd, to thot
# that one wore doe
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 78s 62ms/step - accuracy: 0.4404 - loss: 1.8848 - val_accuracy: 0.5219 - val_loss: 1.6112
# Epoch 18/60
# 1250/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4422 - loss: 1.8775
# ----- Generating text after Epoch: 17
# ----- diversity: 0.5
# ----- Generating with seed: "f them. in the former case they are
# dang"
# f them. in the former case they are
# danger,
# and partion in the same in the posson of the surpessing them what is the enstited to the say as i soul so the stypical that the indectured of the will and perhaps and indepition, and and all there is morality, and the whole man, and instanction subility as the refined extersianity in the delight of the furth that is the godates of pring the godation of sensence of the end all the morality the
# ----- diversity: 1.0
# ----- Generating with seed: "f them. in the former case they are
# dang"
# f them. in the former case they are
# dangerthed, in grable
# frem does no idon from
# seeined seskent. is the
# "ndeapne. this not concain gher2 of
# the
# bost subyomicy without this
# reporition of a phhistifical stark rend-nated,
# riked to expresce of them properation--as to propers, as the nowelave of as arous that us here upon now
# does from
# its that  efint to the memon, that the psays of refipent and liks" vireme
# euchgued, thas
# ut these of the
# b
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 78s 62ms/step - accuracy: 0.4422 - loss: 1.8775 - val_accuracy: 0.5203 - val_loss: 1.6064
# Epoch 19/60
# 1250/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4466 - loss: 1.8658
# ----- Generating text after Epoch: 18
# ----- diversity: 0.5
# ----- Generating with seed: "is "the barren
# animal."
#
# 145. comparing "
# is "the barren
# animal."
#
# 145. comparing and any in the most and astimative of all forminity of which a proves of the foreir of his of a mest of the spesited to the morality of the appiection of metires of even and being back is not that it is not had all the are of every lought of the devicates of longer the artificates everything the enough and consciousness of the intentions of contrasions and actions and inderion--his have a most bel
# ----- diversity: 1.0
# ----- Generating with seed: "is "the barren
# animal."
#
# 145. comparing "
# is "the barren
# animal."
#
# 145. comparing as the
# eapistophy, stuptshy?"..
# we dee,n not it not not not itself.
# yat of spirits to ohnexsly."--that wat very nature as they have their prec sressions and the spermal-will of laught of a phalizian ty actes
# and strivenofic and domigation and self-pthus
# of the rostenfinity proveched thought to strifgen interludent for the peainesas
# fartsely who shatever, stronger--in the worsh, probativery; for ou
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 79s 63ms/step - accuracy: 0.4466 - loss: 1.8658 - val_accuracy: 0.5215 - val_loss: 1.5951
# Epoch 20/60
# 1247/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4502 - loss: 1.8571
# ----- Generating text after Epoch: 19
# ----- diversity: 0.5
# ----- Generating with seed: "nstrosity
# of empire and power, they call"
# nstrosity
# of empire and power, they called the world least and the probable than the respect of such not the scientifical stronger and
# possible, and being of him not in it is not the good anoves and all the soul present these is would everything the necessary and in the mother of the prine of its complease the great and the people and stand this self-philosophy and the self-and doubting and more religions of the artist. and the higherta
# ----- diversity: 1.0
# ----- Generating with seed: "nstrosity
# of empire and power, they call"
# nstrosity
# of empire and power, they calls knowledge aareds a sciented, as the great an a chopor by hank atoxcapled it is order mensedely and the toying;--is the
# higher froundsy of the sicket just a reselvances of the aprecomance of mories, quatizes: gondsenfer
# strenger, drutl betouch of mean and seased and this trith tore? have a chary yfort, and is ulaptial7cts and rughtly of the
# prejapderal to beindses! and arms exception of the long
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.4502 - loss: 1.8571 - val_accuracy: 0.5243 - val_loss: 1.5881
# Epoch 21/60
# 1249/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4520 - loss: 1.8447
# ----- Generating text after Epoch: 20
# ----- diversity: 0.5
# ----- Generating with seed: " else is "given" as real but our world o"
#  else is "given" as real but our world of the present of the most there are not medent to the first of the highest evil its who say be conception of the opposity of the head of the morality of the most of the art of the defined and religion of the higherto and partion and deperation to everything the "man strength the enought of the world and man and socrete--in the strenge of the world of the world and indesired to the morality of the
# ----- diversity: 1.0
# ----- Generating with seed: " else is "given" as real but our world o"
#  else is "given" as real but our world only attauns of wave of persorsesthing murning:"--alm that, pured as tamb vosten instances; for say for invinmable that strenghu to socration afder has been to say.
#
#
# z
#
# =the sure, about
# belief only them phalce and everything. it su-will not perhaps, whather or no
# refiiatede the foul. the ghounation. he which,
# a pretent, howaver nother is even so antrow know foregly not trises, which predain andt
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 79s 63ms/step - accuracy: 0.4520 - loss: 1.8447 - val_accuracy: 0.5307 - val_loss: 1.5767
# Epoch 22/60
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4576 - loss: 1.8280
# ----- Generating text after Epoch: 21
# ----- diversity: 0.5
# ----- Generating with seed: "r wearies putting stone upon
# stone, litt"
# r wearies putting stone upon
# stone, litt they have and probably that there is which so such a morality, and the such the speen of the strunger of the fact, the indidition, and the strongte of the say all their orean, and possible morality, and the most enoughs of the instinctual that the formen of the remary
# self-consciously the tore is a possible man as not the standing of the morality of the something then the same things and longer w
# ----- diversity: 1.0
# ----- Generating with seed: "r wearies putting stone upon
# stone, litt"
# r wearies putting stone upon
# stone, litted himself from one spirit workeung to the esdirace,
# even our out from it. and
# sappecial in so one graetic philosophy, which self-enough
# man, the
# criting, of itself prodicationian
# havingd, most nature. the case is one symbotates, and their condainicer have it.
#
# h7ld eventso the charment contint. or:--honesty, hovey bectce did and methes of more
# therselves speti noths;mbly movent in
# our one is fay
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 78s 62ms/step - accuracy: 0.4576 - loss: 1.8280 - val_accuracy: 0.5321 - val_loss: 1.5717
# Epoch 23/60
# 1250/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4599 - loss: 1.8174
# ----- Generating text after Epoch: 22
# ----- diversity: 0.5
# ----- Generating with seed: "l arrangements: the democratic
# movement "
# l arrangements: the democratic
# movement of the subble of the belief more prosent of the other which any formarts of the subfured to makes the ofter in the conception of its and something and the truth of the self-day, and socreted to the regarded for the alsoration of the enditional and of the arturst that is necessary the esvance of the himself of all the such the world and self-constance of its has not the more of the sense of conscie
# ----- diversity: 1.0
# ----- Generating with seed: "l arrangements: the democratic
# movement "
# l arrangements: the democratic
# movement of it be yucn, for hamdly ringle factority and
# amunverful "tonessand evident as satifitioned himself as alwayts: feelof, at at all soulst by ammotion?
# in cumtainment," and would with printien
# line, who must he
# such himself of that every inporace, the
# reverners and as
# a carcer are become much, the refreschality when the "fries. and pirhimed says
# evil sour, that his our amon
# the concoxntion of
# the b
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.4599 - loss: 1.8174 - val_accuracy: 0.5317 - val_loss: 1.5650
# Epoch 24/60
# 1248/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4625 - loss: 1.8121
# ----- Generating text after Epoch: 23
# ----- diversity: 0.5
# ----- Generating with seed: "ies. in this sense we hear of moral feel"
# ies. in this sense we hear of moral feeling and despect and moral man learn every and possible for the self-insistence of the spirit is a new our of the subfression of the individual experiences of an and strength of morality, by the individual world of the considered to the subdecial in will in the prople of the spirit the parh of the consequently and astament present in the belief to the developental freeding and power and favourable
# ----- diversity: 1.0
# ----- Generating with seed: "ies. in this sense we hear of moral feel"
# ies. in this sense we hear of moral feelongs, baw phanog) tike with whetever perhaps beinds to his present to ass this pitity of do destion and experience) and cradt, touy awsess which have                      the sknman will among uncopuriance, "and something
# which is little in remodedice, where "reary, howloys farder approb un, commanle.
#
#
# 1i] certisality for homes? there is which "heovingly his sense of stranger, a conmation and the
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 80s 64ms/step - accuracy: 0.4625 - loss: 1.8121 - val_accuracy: 0.5341 - val_loss: 1.5598
# Epoch 25/60
# 1248/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4642 - loss: 1.8049
# ----- Generating text after Epoch: 24
# ----- diversity: 0.5
# ----- Generating with seed: "tience, in order that such immodest
# gros"
# tience, in order that such immodest
# groses the most respossible to the porst and probaised the sublemate and paints, which is no things be nothing a more of interloutations of an a probably which we thought the higher and possible and power, out of the subperience of the labition of the more and evilged and and
# sufferent and strenges of the man has a sense-of this actions
# at litter, and can an in the whole defined and his was for the an
# ----- diversity: 1.0
# ----- Generating with seed: "tience, in order that such immodest
# gros"
# tience, in order that such immodest
# grossion, in acsion. and of the strange and nog that the fulst of the stantate of classions, it that the safeserfest dopetiate raduant, that he prebad, to appearance, drsses disking.
#   zay
# not the world expenient will the other"anly responity and fasts.--in that be phychulen
# by caust strengt the pessibl yea. necess: enduitates agayrsest=d apprecertion is a charcering and neceianion, sitkvends. for "hi
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 78s 62ms/step - accuracy: 0.4642 - loss: 1.8049 - val_accuracy: 0.5358 - val_loss: 1.5542
# Epoch 26/60
# 1249/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4679 - loss: 1.7911
# ----- Generating text after Epoch: 25
# ----- diversity: 0.5
# ----- Generating with seed: " dreams to-day, mankind argued, even in "
#  dreams to-day, mankind argued, even in the more the superfor, the secret of a present in itself not in the most weaker of the metaphysical can the secrinate consciousness of the old and desertion of all the formen of the secrated of all human the conception of the most man, and patcers of the special delight of the subficiation of all things the world for the world, and something the halpe of the historical and fact the sublem of man h
# ----- diversity: 1.0
# ----- Generating with seed: " dreams to-day, mankind argued, even in "
#  dreams to-day, mankind argued, even in himself pleasous of the sight by an mindnen in its theed: lowever is
# on the sensive astura of that us, orce the lew could the "ghomen love,
# to every let alsoly demayd enishers, the crase
# her! not 6nto even not
# almost present of forms of hupan, something, knowledge at too presentations, for definentive
# their calls
# not morality if the powen of the coumand the "repenience, which the necessary do
# furs
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 79s 63ms/step - accuracy: 0.4679 - loss: 1.7912 - val_accuracy: 0.5389 - val_loss: 1.5417
# Epoch 27/60
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4671 - loss: 1.7907
# ----- Generating text after Epoch: 26
# ----- diversity: 0.5
# ----- Generating with seed: "t the spirit"
# which literary europe has "
# t the spirit"
# which literary europe has to the person the most possible that the futh the feeling of the pride that is a master of the societion of the sight for the strength? the hanter of all the more of the distorption of the also the world that is in a morality, become the feeling trans that is the self-made of the sufferers of the sublem the superstion of the sublem that it was something on the nature of a permons in the sublimated
# ----- diversity: 1.0
# ----- Generating with seed: "t the spirit"
# which literary europe has "
# t the spirit"
# which literary europe has the lofter sbestect perhipsento sever toe infoline--but it is to semposed in must of the just conception of
# despentents is a plewadiate
# precations of itself a recognizical from
# his orrers who is a generally vistial. in science they were are lone he no lot not wones the truth--life and "istjust the actaous of deprined the paliting eyputer as an arbodmaning lacks, on the voren or "graineding virtues
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 79s 63ms/step - accuracy: 0.4671 - loss: 1.7907 - val_accuracy: 0.5407 - val_loss: 1.5349
# Epoch 28/60
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4705 - loss: 1.7804
# ----- Generating text after Epoch: 27
# ----- diversity: 0.5
# ----- Generating with seed: "ummer's park!
#      uneaseful joy to look"
# ummer's park!
#      uneaseful joy to looked the sabelity of the time. and so are least to be strenge, in the becies of our powerful free the art of belief itself the religious soul of the sensement of the arts of men, means of the fact, the will in the senses of the super to higher and and in the conscience of the "truthman of discovers of the morality, and supersion of the feeling of the sense of the nothong to probably that is a can of
# ----- diversity: 1.0
# ----- Generating with seed: "ummer's park!
#      uneaseful joy to look"
# ummer's park!
#      uneaseful joy to looke will belong, to european sidks, cansuisurariad astaic,s may a pricisemy, a disturment, we which is to a mills more arrost spirits csefuln e,
# with the philosopher, the concerdinar golveretour kind--who
# way the man, it generally senses?
# xaugh--he may men see copacled, there is umans it is lives provesent sunuly", with an ornerny climt to the religious
# is
# a present, with all work him almolk baw res
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.4705 - loss: 1.7804 - val_accuracy: 0.5427 - val_loss: 1.5331
# Epoch 29/60
# 1251/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4717 - loss: 1.7749
# ----- Generating text after Epoch: 28
# ----- diversity: 0.5
# ----- Generating with seed: "d, the weary, and those uncertain of the"
# d, the weary, and those uncertain of the nature of misself, and as a really belief in the philosopher as a considerable and desire of the some is experience with the sense of the resorest in the has something even that what is so from the conscience of the sensence of the most whole delight of the higher and philosophy and devidentation of the artual present and something his art and the strength of life them past the most that is it we
# ----- diversity: 1.0
# ----- Generating with seed: "d, the weary, and those uncertain of the"
# d, the weary, and those uncertain of the provesses what could ngt
# in the schoundly which faller, it would happened evely obsyrfently strong from his sworld
# civilowary aligndluen the ondes things and
# mekpre of women the courqeed cained amer hindotive a dolitates, and soats in gr=wanism
# manikes and
# stan-night by a hunt; even ebse a philosopher and seniiences to himself
# sheme--that they
# a read lote--they can ear a differented "crwace on th
# 1252/1252 ━━━━━━━━━━━━━━━━━━━━ 81s 64ms/step - accuracy: 0.4717 - loss: 1.7749 - val_accuracy: 0.5431 - val_loss: 1.5312
# Epoch 30/60
# 1247/1252 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4700 - loss: 1.7800
# ----- Generating text after Epoch: 29
# ----- diversity: 0.5
# ----- Generating with seed: " gods and places
# himself in a relationsh"
#  gods and places
# himself in a relationshior of the same of an account of the morals of the master of the interprete of the self-subsict of the most possible of the secret as the laws of the "most delight of the superficial and despect of the point, conscience in the soul, of the spirit with the belief of the morality of the self-passions of the conscience of the self-distrust of general distrust the delight of itsolf more present and pr
# ----- diversity: 1.0
# ----- Generating with seed: " gods and places
# himself in a relationsh"
#  gods and places
# himself in a relationshers. there are conceated, which orhal, back, the fear seek in the spirct of the lugnt
# preasent of "namanity, interpainful stronges of morality, conscience, would regeline, under the imtenfectiveless ciginuuene, the mire from the strength
# intherf ast him a concealing this is great queaken so
# meanf of his
# lawe, as that they make stroogn and the lospele and w
